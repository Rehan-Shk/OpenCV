# %%
# Import the required packages:
import cv2

# %%
def decode_fourcc(fourcc):
    """
    Decodes the fourcc value to get the four chars identifying it
    """
    fourcc_int = int(fourcc)
    # We print the int value of fourcc
    print("int value of fourcc: '{}'".format(fourcc_int))
    # We can also perform this in one line:
    # return "".join([chr((fourcc_int >> 8 * i) & 0xFF) for i in range(4)])
    fourcc_decode = ""
    for i in range(4):
        int_value = fourcc_int >> 8 * i & 0xFF
        print("int_value: '{}'".format(int_value))
        fourcc_decode += chr(int_value)
    return fourcc_decode

# %%
capture = cv2.VideoCapture(0)
# Out:
# [ WARN:0@165.509] global cap_gstreamer.cpp:1173 isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created

# %%
# Get and print these values:
print("CV_CAP_PROP_FRAME_WIDTH: '{}'".format(capture.get(cv2.CAP_PROP_FRAME_WIDTH)))
print("CV_CAP_PROP_FRAME_HEIGHT : '{}'".format(capture.get(cv2.CAP_PROP_FRAME_HEIGHT)))
print("CAP_PROP_FPS : '{}'".format(capture.get(cv2.CAP_PROP_FPS)))
print("CAP_PROP_POS_MSEC : '{}'".format(capture.get(cv2.CAP_PROP_POS_MSEC)))
print("CAP_PROP_POS_FRAMES : '{}'".format(capture.get(cv2.CAP_PROP_POS_FRAMES)))
print("CAP_PROP_FOURCC  : '{}'".format(decode_fourcc(capture.get(cv2.CAP_PROP_FOURCC))))
print("CAP_PROP_FRAME_COUNT  : '{}'".format(capture.get(cv2.CAP_PROP_FRAME_COUNT)))
print("CAP_PROP_MODE : '{}'".format(capture.get(cv2.CAP_PROP_MODE)))
print("CAP_PROP_BRIGHTNESS : '{}'".format(capture.get(cv2.CAP_PROP_BRIGHTNESS)))
print("CAP_PROP_CONTRAST : '{}'".format(capture.get(cv2.CAP_PROP_CONTRAST)))
print("CAP_PROP_SATURATION : '{}'".format(capture.get(cv2.CAP_PROP_SATURATION)))
print("CAP_PROP_HUE : '{}'".format(capture.get(cv2.CAP_PROP_HUE)))
print("CAP_PROP_GAIN  : '{}'".format(capture.get(cv2.CAP_PROP_GAIN)))
print("CAP_PROP_EXPOSURE : '{}'".format(capture.get(cv2.CAP_PROP_EXPOSURE)))
print("CAP_PROP_CONVERT_RGB : '{}'".format(capture.get(cv2.CAP_PROP_CONVERT_RGB)))
print("CAP_PROP_RECTIFICATION : '{}'".format(capture.get(cv2.CAP_PROP_RECTIFICATION)))
print("CAP_PROP_ISO_SPEED : '{}'".format(capture.get(cv2.CAP_PROP_ISO_SPEED)))
print("CAP_PROP_BUFFERSIZE : '{}'".format(capture.get(cv2.CAP_PROP_BUFFERSIZE)))
# Out:
# CV_CAP_PROP_FRAME_WIDTH: '640.0'
# CV_CAP_PROP_FRAME_HEIGHT : '480.0'
# CAP_PROP_FPS : '30.0'
# CAP_PROP_POS_MSEC : '0.0'
# CAP_PROP_POS_FRAMES : '-1.0'
# int value of fourcc: '1448695129'
# int_value: '89'
# int_value: '85'
# int_value: '89'
# int_value: '86'
# CAP_PROP_FOURCC  : 'YUYV'
# CAP_PROP_FRAME_COUNT  : '-1.0'
# CAP_PROP_MODE : '0.0'
# CAP_PROP_BRIGHTNESS : '0.0'
# CAP_PROP_CONTRAST : '0.0'
# CAP_PROP_SATURATION : '64.0'
# CAP_PROP_HUE : '0.0'
# CAP_PROP_GAIN  : '1.0'
# CAP_PROP_EXPOSURE : '156.0'
# CAP_PROP_CONVERT_RGB : '1.0'
# CAP_PROP_RECTIFICATION : '-1.0'
# CAP_PROP_ISO_SPEED : '-1.0'
# CAP_PROP_BUFFERSIZE : '4.0'

# %%
# Check if camera opened successfully
if capture.isOpened() is False:
    print("Error opening video stream or file")

# Read until video is completed
while capture.isOpened():
    # Capture frame-by-frame
    ret, frame = capture.read()

    if ret is True:

        # Print current frame number per iteration
        print("CAP_PROP_POS_FRAMES : '{}'".format(capture.get(cv2.CAP_PROP_POS_FRAMES)))

        # Get the timestamp of the current frame in milliseconds
        print("CAP_PROP_POS_MSEC : '{}'".format(capture.get(cv2.CAP_PROP_POS_MSEC)))

        # Display the resulting frame
        cv2.imshow('Original frame', frame)

        # Convert the frame to grayscale:
        gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        # Display the grayscale frame
        cv2.imshow('Grayscale frame', gray_frame)

        # Press q on keyboard to  exit
        if cv2.waitKey(25) & 0xFF == ord('q'):
            break
    # Break the loop
    else:
        break

# Release everything:
capture.release()
cv2.destroyAllWindows()
# Out:
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15427420.104'
# Warning: Ignoring XDG_SESSION_TYPE=wayland on Gnome. Use QT_QPA_PLATFORM=wayland to run on Wayland anyway.
# MESA-LOADER: failed to open radeonsi: /usr/lib/dri/radeonsi_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
# failed to load driver: radeonsi
# MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15427455.888'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15427487.847'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15427523.884'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15427555.865'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15427723.874'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15427791.865'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15427855.864'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15427891.867'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15427959.875'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15427991.923'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15428023.866'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15428059.885'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15428091.9'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15428127.896'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15428159.871'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15428191.869'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15428227.888'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15428259.938'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15428291.897'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15428327.916'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15428359.873'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15428395.901'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15428427.92'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15428459.91'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15428495.878'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15428527.951'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15428563.934'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15428595.903'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15428627.893'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15428663.897'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15428695.885'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15428763.895'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15428795.891'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15428831.884'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15428863.901'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15428895.928'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15428931.912'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15428963.915'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15428999.894'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15429031.889'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15429063.907'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15429099.944'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15429131.986'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15429163.913'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15429199.944'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15429231.918'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15429268.157'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15429299.942'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15429331.89'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15429399.926'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15429435.894'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15429467.902'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15429499.913'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15429535.924'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15429567.924'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15429635.904'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15429667.904'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15429703.936'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15429735.94'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15429767.957'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15429803.976'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15429835.936'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15429871.908'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15429903.916'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15429935.912'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15429971.932'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15430003.943'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15430035.916'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15430071.921'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15430103.919'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15430139.922'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15430171.918'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15430239.926'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15430271.921'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15430339.917'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15430407.935'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15430439.931'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15430523.933'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15430575.934'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15430623.961'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15430675.923'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15430723.923'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15430775.929'
# CAP_PROP_POS_FRAMES : '-1.0'
# CAP_PROP_POS_MSEC : '15430823.921'
